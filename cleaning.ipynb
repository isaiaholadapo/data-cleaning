# %%
import pandas as pd

# %%
data = pd.read_csv('data/unclean_data.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 7: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-e18de8d5818a> in <module>
# ----> 1 data = pd.read_csv('data/unclean_data.csv')
#
# ...

# %%
data = pd.read_csv('data/unclean_data.csv', encoding = 'latin1')

# %%
data.head(10)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
# 5                              Spider-Man 3?ÿ                     392
# 6                                   Tangled?ÿ                     324
# 7                   Avengers: Age of Ultron?ÿ                     635
# 8                   Avengers: Age of Ultron?ÿ                     635
# 9    Harry Potter and the Half-Blood Prince?ÿ                     375
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# ...

# %%
data.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
data.columns = data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_1_facebook_likes', 'gross', 'num_voted_users',
#        'cast_total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(".","_")

# %%
data.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_1_facebook_likes', 'gross', 'num_voted_users',
#        'cast_total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'title_year_1'],
#       dtype='object')

# %%
data.describe()
# Out:
#        num_critic_for_reviews    duration  actor_3_facebook_likes  \
# count               14.000000   11.000000               14.000000
# mean               506.142857  150.727273             5866.142857
# std                169.069789   21.679903             8289.592695
# min                302.000000  106.000000              161.000000
# 25%                379.250000  141.000000              611.250000
# 50%                448.000000  151.000000             1000.000000
# 75%                635.000000  162.500000             8500.000000
# max                813.000000  183.000000            23000.000000
#
#        actor_1_facebook_likes         gross  num_voted_users  \
# count               14.000000  1.400000e+01     1.300000e+01
# mean             18206.428571  3.335836e+08     4.621578e+05
# std              13905.214361  1.720674e+08     2.687059e+05
# min                451.000000  7.305868e+07     2.122040e+05
# 25%               3500.000000  2.002574e+08     2.948100e+05
# ...

# %%
data.shape
# Out:
# (14, 16)

# %%
data.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# director_facebook_likes       object
# actor_3_facebook_likes         int64
# actor_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# cast_total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# title_year_1                 float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# director_facebook_likes      2
# actor_3_facebook_likes       0
# actor_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# cast_total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       1
# imdb_score                   0
# title_year_1                 7
# dtype: int64

# %%
data['duration'] = data['duration'].fillna(data['duration'].mean())

# %%
data.drop(data.index[4], inplace = True)

# %%
data['num_voted_users'] = data['num_voted_users'].fillna(data['num_voted_users'].mean())
data['cast_total_facebook_likes'] = data['cast_total_facebook_likes'].fillna(data['cast_total_facebook_likes'].mean())
data['facenumber_in_poster'] = data['facenumber_in_poster'].fillna(data['facenumber_in_poster'].mean())
data['actor_2_facebook_likes'] = data['actor_2_facebook_likes'].fillna(data['actor_2_facebook_likes'].mean())
data['title_year_1'] = data['title_year_1'].fillna(data['title_year_1'].mean())

# %%
data.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 5                              Spider-Man 3?ÿ                     392
#
#      duration director_facebook_likes  actor_3_facebook_likes  \
# 0  178.000000                      10                     855
# 1  150.727273                     563                    1000
# 2  148.000000                      20                     161
# 3  150.727273                   22000                   23000
# 5  156.000000                      23                    4000
#
#    actor_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
data.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      2
# actor_3_facebook_likes       0
# actor_1_facebook_likes       0
# gross                        0
# num_voted_users              0
# cast_total_facebook_likes    0
# facenumber_in_poster         0
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# title_year_1                 0
# dtype: int64

# %%
data['director_facebook_likes'].fillna(data['director_facebook_likes'].mode()[0], inplace = True)

# %%
data.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_1_facebook_likes       0
# gross                        0
# num_voted_users              0
# cast_total_facebook_likes    0
# facenumber_in_poster         0
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# title_year_1                 0
# dtype: int64
